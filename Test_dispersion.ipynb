# %%
from segmentation import get_indicator

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('rgb1.jpg', cv2.IMREAD_COLOR)
print('RGB image')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print('Segmented image')
img2 = cv2.imread('segment1.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# RGB image
# Segmented image

# %%
get_indicator(img2)
# Out:
# Number of contours: 4
# Percentage( % ): 16.54498794274463
# Index: 0.6617995177097852
# (4, 16.54498794274463, 0.6617995177097852)

# %%
img = cv2.imread('rgb3.jpg', cv2.IMREAD_COLOR)
print('RGB image')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
print('Segmented image')
img2 = cv2.imread('segment3.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# RGB image
# Segmented image

# %%
get_indicator(img2)
# Out:
# Number of contours: 137
# Percentage( % ): 15.972642899801274
# Index: 21.882520772727744
# (137, 15.972642899801274, 21.882520772727744)
